# %% [markdown]
# <a href="https://www.kaggle.com/code/vaibhav2851/airline-passenger-satisfaction-classification?scriptVersionId=143891382" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # About Dataset
#
# ## Context
#
# This dataset contains an airline passenger satisfaction survey. What factors are highly correlated to a satisfied (or dissatisfied) passenger? Can you predict passenger satisfaction?
#
# ### Content
#
# Gender: Gender of the passengers (Female, Male)
#
# Customer Type: The customer type (Loyal customer, disloyal customer)
#
# Age: The actual age of the passengers
#
# Type of Travel: Purpose of the flight of the passengers (Personal Travel, Business Travel)
#
# Class: Travel class in the plane of the passengers (Business, Eco, Eco Plus)
#
# Flight distance: The flight distance of this journey
#
# Inflight wifi service: Satisfaction level of the inflight wifi service (0:Not Applicable;1-5)
#
# Departure/Arrival time convenient: Satisfaction level of Departure/Arrival time convenient
#
# Ease of Online booking: Satisfaction level of online booking
#
# Gate location: Satisfaction level of Gate location
#
# Food and drink: Satisfaction level of Food and drink
#
# Online boarding: Satisfaction level of online boarding
#
# Seat comfort: Satisfaction level of Seat comfort
#
# Inflight entertainment: Satisfaction level of inflight entertainment
#
# On-board service: Satisfaction level of On-board service
#
# Leg room service: Satisfaction level of Leg room service
#
# Baggage handling: Satisfaction level of baggage handling
#
# Check-in service: Satisfaction level of Check-in service
#
# Inflight service: Satisfaction level of inflight service
#
# Cleanliness: Satisfaction level of Cleanliness
#
# Departure Delay in Minutes: Minutes delayed when departure
#
# Arrival Delay in Minutes: Minutes delayed when Arrival
#
# Satisfaction: Airline satisfaction level(Satisfaction, neutral or dissatisfaction)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
import random

plt.rcParams['figure.facecolor'] = '#eeeee4'
color = ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r']

# %%
df = pd.read_csv('/kaggle/input/airline-passenger-satisfaction/train.csv')

# %%
df

# %%
df['satisfaction'].unique()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.drop(columns=['Unnamed: 0','id'],inplace=True)

# %%
df

# %%
df.describe()

# %%
df.head()

# %%
df['Arrival Delay in Minutes'].plot(kind='kde')

# %%
df['Arrival Delay in Minutes'].mode()

# %%
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(0)

# %%
df['Arrival Delay in Minutes'].isnull().sum()

# %%
df.head()

# %%
px.bar(df['Gender'].value_counts(),color=df['Gender'].value_counts())

# %% [markdown]
# ### Female  passengers are more than men passenger

# %%
df['satisfaction'].value_counts()

# %%
df.info()

# %%
cat_col = df.select_dtypes('object').columns

# %%
child=[]
adult=[]
old=[]
for i in df['Age']:
    if i < 18:
        child.append(i)
    if i >=18 & i < 65:
        adult.append(i)
    if i > 65 :
        old.append(i)
    
data = [len(child),len(adult),len(old)]
data

# %%
fig=plt.figure(figsize=(10,10))

plt.subplot(221)
plt.pie(data,labels=['child','adult','old'],autopct='%1.1f%%',colors=sns.color_palette('Set2'), explode=[0.15,0.01,0.01],shadow=True)


plt.subplot(222)
plt.bar(height=data,x=['child','adult','old'])
plt.suptitle("Passengers by age",fontsize=16)
fig.tight_layout(pad=5.0)

# %%
import seaborn as sns

# %% [markdown]
# ### Most passengers are adult than other
# - Adult Passengers are 89.7 %

# %%
# df['Gender']

# %%
plt.figure(figsize=(20,15))

plt.suptitle('Customers Data',fontsize=20)
plt.rcParams['figure.facecolor'] = '#eeeee4'

plt.subplot(321)
plt.title('Customers Gender')
sns.countplot(x=df['Gender'],palette='Set1')


plt.subplot(322)
plt.title('Type of Travel')
sns.countplot(x=df['Type of Travel'],palette='Wistia')

plt.subplot(323) 
plt.title('Customer Satisfaction')
sns.countplot(x=df['satisfaction'],palette='cividis')

plt.subplot(324) 
plt.title('Class')
sns.countplot(x=df['Class'],palette='Spectral')

plt.subplot(325)
plt.title('Customer Type')
sns.countplot(x=df['Customer Type'],palette='cool')

# fig.tight_layout(pad=5.0)
# plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(15,10))

# ax = ax.flatten()
for i in range(len(cat_col)):
    plt.title(cat_col[i])        
    sns.countplot(x=df[cat_col[i]],palette=random.choice(color),ax=axes[i//2,i%2])

# %% [markdown]
# ### Customers Data
# - Female passenger more than men
# - More amount of customers travel for bussiness purpose
# - Most of passengers are Neutral or Dissatisfied
# - Max number of passenger travel in Business class then Eco and at last Eco Plus
# - Number Loyal Customers are more

# %%
plt.figure(figsize=(15,15))

# plt.rcParams['figure.facecolor'] = '#A8B7AB'
plt.suptitle('Customers Data',fontsize=20)

plt.subplot(321)
plt.pie(df['Customer Type'].value_counts(),autopct='%1.1f%%',labels=['Loyal','Disloyal'],colors=sns.color_palette('Set2'), explode=[0, 0.12],shadow=True)
plt.title('Customer Type')

plt.subplot(322)
plt.pie(df['Class'].value_counts(),autopct='%1.1f%%',labels=['Business','Eco','Eco plus'], explode=[0.01,0.01,0.15],colors=sns.color_palette('autumn_r'),shadow=True)
plt.title('Class')


plt.subplot(323) 
plt.pie(df['Type of Travel'].value_counts(),autopct='%1.1f%%',labels=['Bussines travel','Personal travel'], explode=[0, 0.1],colors=sns.color_palette('cool'),shadow=True)
plt.title('Type of Travel')

plt.subplot(324) 
plt.pie(df['Gender'].value_counts(),autopct='%1.1f%%',labels=['Female','Male'], explode=[0, 0.1],colors=sns.color_palette('coolwarm'),shadow=True)
plt.title('Customers Gender')

plt.subplot(325)
plt.pie(df['satisfaction'].value_counts(),autopct='%1.1f%%',labels=['neutral or dissatisfied','satisfied'],explode=[0, 0.1],colors=sns.color_palette('Set3'),shadow=True
)
plt.title('Customer Satisfaction')

plt.show()

# %% [markdown]
# ###  Customers Data in Percentage
#
# - __Female passenger are 50.7% and  mens are 49.3%__
#
# - __69 % of people travel for bussiness purpose and 31 % people travel for their personal purpose__
#
# - __56.7 % of passengers are Neutral or Dissatisfied and 43.3 % are satisfied, so maximum number of passengers are not satisfied__
#
# - __47.8 % of passenger travel in Business class then 45 % Eco class and at last7.2 % Eco Plus,so most of people choose business and Eco class__
#
# - __81.7 % of passengers are  Loyal Customers and 18.3 % are disloyal__

# %%
df.info()

# %%
df['Arrival Delay in Minutes'].mean()

# %%
df.groupby('satisfaction')['Arrival Delay in Minutes'].mean()

# %%
df.select_dtypes(exclude='object').columns

# %%
sns.kdeplot(df['Arrival Delay in Minutes'])

# %%
px.box(df['Age'])

# %% [markdown]
# ### Minimum age of passenger is 7 and maximum age is 85

# %%
 sns.histplot(df['Flight Distance'], kde=True,color='blue')

# %%
sns.histplot(df['Age'])

# %%
plt.figure(figsize=(3,10))
def customer_rating(data):
    plt.suptitle('Customer Rating For All Services',fontsize=20,horizontalalignment='center')

    for i in range(len(rate_col)):
        fig, ax = plt.subplots(1, 2, figsize=(16, 5))
        ax = ax.flatten()
        plt.title(rate_col[i])        
        sns.countplot(x=df[rate_col[i]],palette=random.choice(color),ax=ax[0])

        ax[1].pie(df[rate_col[i]].value_counts(),autopct='%1.1f%%',shadow=True)
    plt.show()

# %%
rate_col = df.select_dtypes(exclude='object').columns
rate_col= rate_col[2:-2]
customer_rating(rate_col)
rate_col

# %%
fig, axes = plt.subplots(7, 2, figsize=(25,40))
# fig.suptitle('Customer Rating For All Services',fontsize=20)


for i in range(len(rate_col)):
    plt.title(rate_col[i],fontsize=20)        
    sns.countplot(x=df[rate_col[i]],palette=random.choice(color),ax=axes[i//2,i%2])

# %% [markdown]
# ###  Customer Rating for all airline services
#
#
# - __Inflight WIFI Service has max rating 2 & 3 star, So wifi service not too good in flight.__
#
# - __Departure/ Arrival time convenient is also good or in time 50 % of customers are satisfied with this service.__
# - __50 % of people are book online tickets.__
# - __Seats are comfortable.__
# - __Inflight entertainment is also satsfied.__
# - __On-board  service is good.__
# - <i> All airline Services are satisfied. <i>

# %%
df.groupby('Gender')['satisfaction'].value_counts().unstack().plot(kind='bar',rot=0)
plt.legend(loc='upper center')

# %%
df.groupby('satisfaction')['Age'].mean().plot(kind='pie',autopct='%1.1f%%',shadow=True,explode=[0.1,0.01])

# %%
df.groupby('Type of Travel')['satisfaction'].value_counts().unstack().plot.bar(rot=0)

# %%
df.groupby('Type of Travel')['satisfaction'].value_counts().unstack().plot(kind='bar',rot=0)

# %%
df.groupby('Customer Type')['satisfaction'].value_counts().unstack().plot(kind='bar',rot=0)

# %%
df.groupby('Class')['satisfaction'].value_counts().unstack().plot(kind='bar',rot=0);

# %%
plt.pie(df['Cleanliness'].value_counts(),autopct='%1.1f%%',explode=[0.05,0.05,0.05,0.05,0.05,.05],shadow=True);

# %%
df.select_dtypes(exclude='object').describe()

# %%
px.box(df['Flight Distance'])

# %%
df['Flight Distance'].describe()

# %% [markdown]
# [](http://)

# %% [markdown]
# ### Outlier Treatment using log function

# %%
import numpy as np
df['Flight Distance'] = np.log(df['Flight Distance']) 
df['Flight Distance'].hist(bins=20) 
# df['Flight Distance']= np.log(test['LoanAmount'])

# %%
DF = df.copy()

# %% [markdown]
# ### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
x_enc = df.copy()
for col in df[cat_col].columns:
    lb = LabelEncoder()
    x_enc[col] = lb.fit_transform(df[col].values)
x_enc.head()

# %%
x = x_enc.drop(columns='satisfaction')

# %%
y = x_enc['satisfaction']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
# plt.rcdefaults()
f, ax = plt.subplots(figsize=(20, 14)) 
sns.set(font_scale=1.2)
matrix =df.select_dtypes(exclude='object').corr()
sns.heatmap(matrix, vmax=.8, square=True, cmap="coolwarm",fmt='.2f',annot=True)
plt.show()

# %% [markdown]
# ### Dropped Maximum corelated columns to reduce our data set

# %%
x_enc.drop(columns=['Arrival Delay in Minutes','Cleanliness','Inflight wifi service','Seat comfort'],inplace=True)
x= x_enc.drop(columns='satisfaction')
y= x_enc['satisfaction']
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lg = LogisticRegression()
lg.fit(x_train,y_train)

# %%
pred_test = lg.predict(x_test)
accuracy_score(y_test,pred_test)

# %%
pred_test = lg.predict(x_test)
pred_test

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)

# %%
knn.score(x_test,y_test)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb=GaussianNB()

# %%
nb.fit(x_train,y_train)

# %%
nb.score(x_test,y_test)

# %%
from sklearn.svm import SVC

# %%
svm = SVC()
svm.fit(x_train,y_train)

# %%
svm.score(x_test,y_test)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
dt.score(x_test,y_test)

# %%
sns.set_theme()

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(25, 15))
dt.fit(x_train[:100],y_train[:100])
plot_tree(dt,feature_names=x_train.columns,class_names=df['satisfaction'].unique(),filled=True)
plt.show()

# %%
score=[nb.score(x_test,y_test),knn.score(x_test,y_test),lg.score(x_test,y_test),dt.score(x_test,y_test),svm.score(x_test,y_test)]
sc = pd.DataFrame(index=['Navie Bayes','KNN','Logistic Regression','Decision Tree','SVM'],data=score,columns=['test_score'])
sc

# %%
tr_sc =[nb.score(x_train,y_train),knn.score(x_train,y_train),lg.score(x_train,y_train),dt.score(x_train,y_train),svm.score(x_train,y_train)]
sc['train_score']=tr_sc

# %%
sc['Algorithm']=sc.index

# %%
px.bar(sc,x='Algorithm',y=sc.columns,title='Accuracy of All Classification Algorithms',color=sc.index)

# %%
sc.plot(x='Algorithm', y=["test_score", "train_score"], kind="bar")

# %% [markdown]
# ### All models are trained perfectly except KNN

# %% [markdown]
# # Ensemble Algorithms

# %% [markdown]
# ### 1.Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(4)
rf.fit(x_train,y_train)

# %%
rf.score(x_test,y_test),rf.score(x_train,y_train)

# %%
rf.feature_importances_

# %%
feature_importance = pd.DataFrame({'importance': rf.feature_importances_}, index= x.columns).sort_values('importance')
feature_importance

# %%
feature_importance.plot(kind='bar')

# %%
to_keep = feature_importance[feature_importance['importance']>0.03].index

rf=RandomForestClassifier(4,criterion='entropy',n_jobs=-1)
x_tr,x_ts,y_tr,y_ts = train_test_split(x[to_keep],y)
rf.fit(x_tr,y_tr)
rf.score(x_ts,y_ts),rf.score(x_tr,y_tr),

# %%
ypred = rf.predict(x_ts)
accuracy_score(y_ts,ypred)

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred = rf.predict(x_ts)
print(classification_report(y_ts, y_pred))

# %% [markdown]
# ### 2. Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=0).fit(x_tr, y_tr)
                                 
clf.score(x_ts, y_ts)
y_pred = clf.predict(x_ts)
accuracy_score(y_pred,y_ts)

# %% [markdown]
# ### 3.Ada Boost

# %%
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import accuracy_score
# here best estimator is decision tree
ada_classifier = AdaBoostClassifier(base_estimator=dt, n_estimators=50, random_state=42)

ada_classifier.fit(x_tr, y_tr)
y_pred_ada = ada_classifier.predict(x_ts)


accuracy_ada = accuracy_score(y_ts, y_pred_ada)

print("AdaBoost Accuracy:", accuracy_ada)

# %% [markdown]
# ### 4. XGBoost

# %%
from xgboost import XGBClassifier

# %%
xg = XGBClassifier(n_estimators=50, max_depth=4)     
xg.fit(x_tr, y_tr)   
xg.score(x_ts,y_ts)

y_pred = xg.predict(x_ts)

accuracy_score(y_ts,ypred)

# %% [markdown]
# ### 5. Stacking

# %%
from sklearn.ensemble import StackingClassifier

# Create individual classifiers
clf1 = LogisticRegression(random_state=42)
clf2 = DecisionTreeClassifier(random_state=42)
clf3 = GaussianNB()

# Create a list of base estimators
base_estimators = [('lr', clf1), ('dt', clf2), ('svc', clf3)]

# Create a Stacking Classifier with a meta-estimator (Logistic Regression in this example)
stacking_classifier = StackingClassifier(estimators=base_estimators, final_estimator=LogisticRegression(), cv=5)

# Fit the stacking classifier to the training data
stacking_classifier.fit(x_tr, y_tr)

# Make predictions on the test data
y_pred_stacking = stacking_classifier.predict(x_ts)

# Calculate accuracy
accuracy_stacking = accuracy_score(y_ts, y_pred_stacking)

print("Stacking Accuracy:", accuracy_stacking)

# %% [markdown]
# ### 6.LGBM(Light Gradient Boosting Machine)

# %%
import lightgbm as lgb

lgb = lgb.LGBMClassifier()
lgb.fit(x_tr, y_tr)
lgb.score(x_ts,y_ts)

# %% [markdown]
# ### 7.Cat Boost

# %%
# !pip install catboost

import catboost
from catboost import CatBoostClassifier


# Create a CatBoostClassifier

catboost_classifier = CatBoostClassifier(iterations=100, learning_rate=0.05, depth=6, loss_function='MultiClass');

# Fit the classifier to the training data

catboost_classifier.fit(x_tr, y_tr);

# Make predictions on the test data

y_pred = catboost_classifier.predict(x_ts);

# Calculate accuracy

accuracy = accuracy_score(y_ts, y_pred);

print("CatBoost Accuracy:", accuracy);

# %%
test_ensemble =[rf.score(x_ts,y_ts),clf.score(x_ts,y_ts),ada_classifier.score(x_ts,y_ts),xg.score(x_ts,y_ts),stacking_classifier.score(x_ts,y_ts),lgb.score(x_ts,y_ts),catboost_classifier.score(x_ts,y_ts)]

# %%
ensemble_algo=['Random Forest','Gradient Boost','Ada Boost','XGBoost','Stacking','LGBM','Cat Boost']

# %%
ensemble = pd.DataFrame(data=test_ensemble,index=ensemble_algo,columns=['test_score'])

# %%
print('Training set score: {:.4f}'.format(lgb.score(x_tr, y_tr)))

print('Test set score: {:.4f}'.format(lgb.score(x_ts, y_ts)))

# %%
px.bar(ensemble,color=ensemble.index)

# %%
train_ensemble =[rf.score(x_tr,y_tr),clf.score(x_tr,y_tr),ada_classifier.score(x_tr,y_tr),xg.score(x_tr,y_tr),stacking_classifier.score(x_tr,y_tr),lgb.score(x_tr,y_tr),catboost_classifier.score(x_tr,y_tr)]
ensemble['train_score'] = train_ensemble

# %%
ensemble['algorithm']=ensemble.index

# %%
px.bar(ensemble,color=ensemble.algorithm,title='Score of All Ensemble Algorithms')

# %%
ensemble.plot(x='algorithm',y=['test_score','train_score'],kind='bar',legend=False)

# %% [markdown]
# ### Train score and test score of Gradient Boost , LGBM, XGBoost and Cat boost is same

# %%
sns.lineplot(data=ensemble)

# %%
y_test = y_ts.reset_index(drop=True)
y_test
scr=rf.predict(x_ts)
c=0
for i in range(len(scr)):
    if scr[i] == y_test[i]:
        c+=1
    

print('Number of value Actual values : ',len(y_test))
print('Number of predicted values : ',c)

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV # for hyperparameter tuning
param_dist = {"max_depth": [3, None],
              "max_features": range(1, 11),
              "min_samples_split": range(2, 20),
              "criterion": ["gini", "entropy"]}

# %%
random_search = RandomizedSearchCV(dt,param_distributions=param_dist,cv=5)
random_search.fit(x_tr,y_tr)

# %%
random_search.best_score_

# %%
random_search.best_estimator_

# %%
random_search.best_params_

# %%
dt = DecisionTreeClassifier(min_samples_split= 13,
 max_features= 5,
 max_depth = None,
 criterion= 'gini')
dt.fit(x_tr,y_tr)
dt.score(x_ts,y_ts)
